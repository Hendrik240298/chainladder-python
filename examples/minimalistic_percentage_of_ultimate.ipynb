# %%
import chainladder as cl

# Load triangle data
raa = cl.load_sample('raa')

# Basic visualization showing both individual and average patterns
fig = raa.percent_of_ultimate()

# %%
quarterly = cl.load_sample('quarterly')
fig = quarterly['incurred'].percent_of_ultimate(show_origin_years_in_legend=True,
                                    selected_origins=[2005, 1998, 2000, 2003],
                                    show_average_pattern=False,
                                    )
# Out:
# /home/hendrik/Code/chainladder-python/chainladder/core/base.py:368: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   datetime_mapping = dict(zip(datetime_arg, pd.to_datetime(**date_inference)))

# %%
# Load a triangle with more variability
raa = cl.load_sample('raa')

print(raa)

dev_vol = cl.Development(average='volume').fit(raa)
dev_simple = cl.Development(average='simple').fit(raa)

print(dev_vol.cdf_) 
print(dev_simple.cdf_)

fig1 = raa.percent_of_ultimate(show_by_accident_year=True,
                        average='simple',
                        show_average_pattern=False,
                        selected_origins=[1981],
                        ) 
fig2 = raa.percent_of_ultimate(show_by_accident_year=True,
                        average='volume',
)
# Out:
#          12       24       36       48       60       72       84       96       108      120
# 1981  5012.0   8269.0  10907.0  11805.0  13539.0  16181.0  18009.0  18608.0  18662.0  18834.0
# 1982   106.0   4285.0   5396.0  10666.0  13782.0  15599.0  15496.0  16169.0  16704.0      NaN
# 1983  3410.0   8992.0  13873.0  16141.0  18735.0  22214.0  22863.0  23466.0      NaN      NaN
# 1984  5655.0  11555.0  15766.0  21266.0  23425.0  26083.0  27067.0      NaN      NaN      NaN
# 1985  1092.0   9565.0  15836.0  22169.0  25955.0  26180.0      NaN      NaN      NaN      NaN
# 1986  1513.0   6445.0  11702.0  12935.0  15852.0      NaN      NaN      NaN      NaN      NaN
# 1987   557.0   4020.0  10946.0  12314.0      NaN      NaN      NaN      NaN      NaN      NaN
# 1988  1351.0   6947.0  13112.0      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1989  3133.0   5395.0      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...
